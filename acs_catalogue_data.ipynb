# %%
# this notebook builds a catalogue for ACS bias adjust data in 
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-output/AGCD-05i
# this is a useful way to record all available data within a directory for easy searching and selection

# %%
cd ~/bom-toolbox/
# Out:
# /home/563/gt3409/bom-toolbox

# %%
from CCVE_toolbox.catalog_builder import build_catalog

# %%
import dask
from dask.distributed import Client, LocalCluster
dask.config.set({'distributed.worker.daemon': False})
# cluster = LocalCluster(n_workers=40, processes=True, threads_per_worker=1)
client = Client()  # start distributed scheduler locally.
client
# clie
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37767 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:33323' processes=2 threads=2, memory=9.00 GiB>

# %%
# import modules
import pathlib
import traceback
import re
import glob
import os
import time

from ecgtools import Builder, RootDirectory, glob_to_regex
from ecgtools.builder import INVALID_ASSET, TRACEBACK

# %%
def acs_parser(file):
    """
    Extract attributes of a file using information from Directory structure.

    '/g/data/ia39/australian-climate-service/test-data/\
    CORDEX-CMIP6/bias-adjustment-output/AGCD-05i/BOM/ACCESS-CM2/ssp370/r4i1p1f1/BARPA-R/v1-r1-ACS-QME-BARRA-R2-1980-2022/day/tasmaxAdjust/'

    Directory structure =
    <mip_era>/
        <product>/
            <domain>/
                <institution_id>/
                    <parent_model>/
                        <experiment_id>/
                            <member_id>/
                                <downscaling_model>/
                                    <bias_adjustment>/
                                        <table_id>/
                                            <variable_id>/

    eg tasmaxAdjust_AGCD-05i_ACCESS-CM2_ssp370_r4i1p1f1_BOM_BARPA-R_v1-r1-ACS-QME-BARRA-R2-1980-2022_day_20240101-20241231.nc
    filename = <variable_id>_<domain>_<parent_model>_<experiment_id>_<member_id>_<institution_id>_<downscaling_model>_<bias_adjustment>_<table_id>[_<time_range>].nc
    
    """

    try:
        filep = pathlib.Path(file)
        stem_split = filep.stem.split('_')
        path_split = str(filep.parent).split(filep.anchor)
        
        mip_era, product, domain, institution_id, parent_model, experiment_id, member_id, downscaling_model, bias_adjustment, table_id, variable_id = path_split[-11:]
        
        info = {'institution_id':institution_id,
                'variable_id':variable_id,
                'table_id':table_id,
                'source_id':parent_model,
                'downscaling_model':downscaling_model,
                'experiment_id':experiment_id,
                'member_id':member_id,
                'grid_label':domain,
                'bias_adjustment':bias_adjustment,
                'time_range':0,
                'path':file
        }
        if len(stem_split)>9:
            info["time_range"] = stem_split[-1]
            
        return info
            
    except Exception:
        return {INVALID_ASSET: file, TRACEBACK: traceback.format_exc()}

# %%
# %%time
b= build_catalog(paths_list=["/g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-output/AGCD-05i"], 
              parser=acs_parser,
              catalog_name="nci-acs_bias_corrected",
              directory="/g/data/mn51/users/gt3409")
# Out:
# building catalog : nci-acs_bias_corrected
# saving catalog : nci-acs_bias_corrected
# Successfully wrote ESM catalog json file to: file:///g/data/mn51/users/gt3409/nci-acs_bias_corrected.json
# CPU times: user 10.7 s, sys: 8.78 s, total: 19.4 s
# Wall time: 3min 34s

# %%
b.df
# Out:
#       institution_id   variable_id table_id   source_id downscaling_model  \
# 0                BOM      prAdjust      day  ACCESS-CM2           BARPA-R
# 1                BOM      prAdjust      day  ACCESS-CM2           BARPA-R
# 2                BOM      prAdjust      day  ACCESS-CM2           BARPA-R
# 3                BOM      prAdjust      day  ACCESS-CM2           BARPA-R
# 4                BOM      prAdjust      day  ACCESS-CM2           BARPA-R
# ...              ...           ...      ...         ...               ...
# 71997         UQ-DES  tasminAdjust      day  NorESM2-MM      CCAMoc-v2112
# 71998         UQ-DES  tasminAdjust      day  NorESM2-MM      CCAMoc-v2112
# 71999         UQ-DES  tasminAdjust      day  NorESM2-MM      CCAMoc-v2112
# 72000         UQ-DES  tasminAdjust      day  NorESM2-MM      CCAMoc-v2112
# 72001         UQ-DES  tasminAdjust      day  NorESM2-MM      CCAMoc-v2112
#
#       experiment_id member_id grid_label                   bias_adjustment  \
# 0        historical  r4i1p1f1   AGCD-05i    v1-r1-ACS-MRNBC-AGCD-1960-2022
# 1        historical  r4i1p1f1   AGCD-05i    v1-r1-ACS-MRNBC-AGCD-1960-2022
# 2        historical  r4i1p1f1   AGCD-05i    v1-r1-ACS-MRNBC-AGCD-1960-2022
# 3        historical  r4i1p1f1   AGCD-05i    v1-r1-ACS-MRNBC-AGCD-1960-2022
# 4        historical  r4i1p1f1   AGCD-05i    v1-r1-ACS-MRNBC-AGCD-1960-2022
# ...             ...       ...        ...                               ...
# 71997        ssp370  r1i1p1f1   AGCD-05i  v1-r1-ACS-QME-BARRA-R2-1980-2022
# 71998        ssp370  r1i1p1f1   AGCD-05i  v1-r1-ACS-QME-BARRA-R2-1980-2022
# 71999        ssp370  r1i1p1f1   AGCD-05i  v1-r1-ACS-QME-BARRA-R2-1980-2022
# 72000        ssp370  r1i1p1f1   AGCD-05i  v1-r1-ACS-QME-BARRA-R2-1980-2022
# 72001        ssp370  r1i1p1f1   AGCD-05i  v1-r1-ACS-QME-BARRA-R2-1980-2022
#
#               time_range                                               path
# 0      19600101-19601231  /g/data/ia39/australian-climate-service/test-d...
# 1      19610101-19611231  /g/data/ia39/australian-climate-service/test-d...
# 2      19620101-19621231  /g/data/ia39/australian-climate-service/test-d...
# 3      19630101-19631231  /g/data/ia39/australian-climate-service/test-d...
# 4      19640101-19641231  /g/data/ia39/australian-climate-service/test-d...
# ...                  ...                                                ...
# 71997  20960101-20961231  /g/data/ia39/australian-climate-service/test-d...
# 71998  20970101-20971231  /g/data/ia39/australian-climate-service/test-d...
# 71999  20980101-20981231  /g/data/ia39/australian-climate-service/test-d...
# 72000  20990101-20991231  /g/data/ia39/australian-climate-service/test-d...
# 72001  21000101-21001231  /g/data/ia39/australian-climate-service/test-d...
#
# [72002 rows x 11 columns]
